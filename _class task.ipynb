# %% [markdown]
# https://drive.google.com/file/d/1etGP85wJWsgqbsh3gX5oxc8dPKLMA1eT/view
#
# https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv
# https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt
# https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv
# https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv
# query@ineuron.ai

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv',sep='\t')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
#Removing '$' from the data 
df[df.columns[4]] = df[df.columns[4]].replace('[\$,\.]',"",regex=True).astype(int)
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description  item_price
# 0                                                   NaN         239
# ...

# %%
df.shape
# Out:
# (4622, 5)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
#which item cost more
df[df["item_price"] == max(df['item_price'])]
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598        4425

# %%
#Replacing NaN 
ser = df['choice_description'][df['choice_description'].isnull() == True]

# %%
ser
# Out:
# 0       NaN
# 3       NaN
# 6       NaN
# 10      NaN
# 14      NaN
#        ...
# 4600    NaN
# 4605    NaN
# 4613    NaN
# 4614    NaN
# 4616    NaN
# Name: choice_description, Length: 1246, dtype: object

# %%
ser.index
# Out:
# Int64Index([   0,    3,    6,   10,   14,   15,   20,   25,   30,   32,
#             ...
#             4582, 4584, 4588, 4596, 4598, 4600, 4605, 4613, 4614, 4616],
#            dtype='int64', length=1246)

# %%
#Replacing NaN values with 0
ser = df['choice_description'][df['choice_description'].isnull() == True].fillna(0)

# %%
ser
# Out:
# 0       0
# 3       0
# 6       0
# 10      0
# 14      0
#        ..
# 4600    0
# 4605    0
# 4613    0
# 4614    0
# 4616    0
# Name: choice_description, Length: 1246, dtype: int64

# %%
#What was the quantity of the most expensive item ordered?
df.sort_values(by = "item_price",ascending=False).head(1)
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598        4425

# %%
#How many times Steak Bowl was ordered?
df[df.item_name == 'Steak Bowl']
# Out:
#       order_id  quantity   item_name  \
# 54          25         1  Steak Bowl
# 86          38         1  Steak Bowl
# 90          40         1  Steak Bowl
# 91          40         1  Steak Bowl
# 102         45         1  Steak Bowl
# ...        ...       ...         ...
# 4427      1764         2  Steak Bowl
# 4449      1773         1  Steak Bowl
# 4459      1777         1  Steak Bowl
# 4470      1781         1  Steak Bowl
# 4518      1796         1  Steak Bowl
#
#                                      choice_description  item_price
# 54    [Fresh Tomato Salsa (Mild), [Black Beans, Rice...         899
# 86    [Tomatillo-Red Chili Salsa (Hot), [Pinto Beans...         899
# 90    [Fresh Tomato Salsa, [Rice, Black Beans, Chees...        1175
# 91    [Fresh Tomato Salsa, [Fajita Vegetables, Chees...        1175
# 102   [Tomatillo-Green Chili Salsa (Medium), [Rice, ...         899
# ...                                                 ...         ...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/beer.txt')

# %%
#cleaning data 
df = pd.DataFrame({'Name':['Budweiser','Schlitz','Lowenbrau','Kronenbourg','Heineken','Old_Milwaukee','Augsberger','Srohs_Bohemian_Style','Miller_Lite','Budweiser_Light','Coors',' Coors_Ligh','Michelob_Light','Becks','Kirin','Pabst_Extra_Light','Hamms','Heilemans_Old_Style','Olympia_Goled_Ligh','Schlitz_Light'],'Calories':[144,151,157,170,152,145,175,149,99,113,140,102,135,150,149,68,139,144,72,97],'sodium':[15,19,15,7,11,23,24,27,10,8,18,15,11,19,6,15,19,24,6,7],'alcohol':[4.7,4.9,0.9,5.2,5.0,4.6,5.5,4.7,4.3,3.7,4.6,4.1,4.2,4.7,5.0,2.3,4.4,4.9,2.9,4.2],'cost':[0.43,0.43,0.48,0.73,0.77,0.28,0.40,0.42,0.43,0.40,0.44,0.46,0.50,0.76,0.79,0.38,0.43,0.43,0.46,0.47]})

# %%
df
# Out:
#                     Name  Calories  sodium  alcohol  cost
# 0              Budweiser       144      15      4.7  0.43
# 1                Schlitz       151      19      4.9  0.43
# 2              Lowenbrau       157      15      0.9  0.48
# 3            Kronenbourg       170       7      5.2  0.73
# 4               Heineken       152      11      5.0  0.77
# 5          Old_Milwaukee       145      23      4.6  0.28
# 6             Augsberger       175      24      5.5  0.40
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42
# 8            Miller_Lite        99      10      4.3  0.43
# 9        Budweiser_Light       113       8      3.7  0.40
# 10                 Coors       140      18      4.6  0.44
# 11            Coors_Ligh       102      15      4.1  0.46
# 12        Michelob_Light       135      11      4.2  0.50
# 13                 Becks       150      19      4.7  0.76
# 14                 Kirin       149       6      5.0  0.79
# ...

# %%
df.head()
# Out:
#           Name  Calories  sodium  alcohol  cost
# 0    Budweiser       144      15      4.7  0.43
# 1      Schlitz       151      19      4.9  0.43
# 2    Lowenbrau       157      15      0.9  0.48
# 3  Kronenbourg       170       7      5.2  0.73
# 4     Heineken       152      11      5.0  0.77

# %%
df.columns
# Out:
# Index(['Name', 'Calories', 'sodium', 'alcohol', 'cost'], dtype='object')

# %%
#Which beer has higher calories
df[df["Calories"] == max(df['Calories'])]
# Out:
#          Name  Calories  sodium  alcohol  cost
# 6  Augsberger       175      24      5.5   0.4

# %%
#which beer cost more?
df[df["cost"] == max(df['cost'])]
# Out:
#      Name  Calories  sodium  alcohol  cost
# 14  Kirin       149       6      5.0  0.79

# %%
#Manipulating the index
df.set_index('cost')
# Out:
#                       Name  Calories  sodium  alcohol
# cost
# 0.43             Budweiser       144      15      4.7
# 0.43               Schlitz       151      19      4.9
# 0.48             Lowenbrau       157      15      0.9
# 0.73           Kronenbourg       170       7      5.2
# 0.77              Heineken       152      11      5.0
# 0.28         Old_Milwaukee       145      23      4.6
# 0.40            Augsberger       175      24      5.5
# 0.42  Srohs_Bohemian_Style       149      27      4.7
# 0.43           Miller_Lite        99      10      4.3
# 0.40       Budweiser_Light       113       8      3.7
# 0.44                 Coors       140      18      4.6
# 0.46            Coors_Ligh       102      15      4.1
# 0.50        Michelob_Light       135      11      4.2
# 0.76                 Becks       150      19      4.7
# 0.79                 Kirin       149       6      5.0
# 0.38     Pabst_Extra_Light        68      15      2.3
# ...

# %%
#Combinig
df['new_col'] = df['sodium'] + df['alcohol']
df
# Out:
#                     Name  Calories  sodium  alcohol  cost  new_col
# 0              Budweiser       144      15      4.7  0.43     19.7
# 1                Schlitz       151      19      4.9  0.43     23.9
# 2              Lowenbrau       157      15      0.9  0.48     15.9
# 3            Kronenbourg       170       7      5.2  0.73     12.2
# 4               Heineken       152      11      5.0  0.77     16.0
# 5          Old_Milwaukee       145      23      4.6  0.28     27.6
# 6             Augsberger       175      24      5.5  0.40     29.5
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42     31.7
# 8            Miller_Lite        99      10      4.3  0.43     14.3
# 9        Budweiser_Light       113       8      3.7  0.40     11.7
# 10                 Coors       140      18      4.6  0.44     22.6
# 11            Coors_Ligh       102      15      4.1  0.46     19.1
# 12        Michelob_Light       135      11      4.2  0.50     15.2
# ...

# %%
df = pd.DataFrame({'Name':['Budweiser','Schlitz','Lowenbrau','Kronenbourg','Heineken','Old_Milwaukee','Augsberger','Srohs_Bohemian_Style','Miller_Lite','Budweiser_Light','Coors',' Coors_Ligh','Michelob_Light','Becks','Kirin','Pabst_Extra_Light','Hamms','Heilemans_Old_Style','Olympia_Goled_Ligh','Schlitz_Light'],'Calories':[144,151,157,170,152,145,175,149,99,113,140,102,135,150,149,68,139,144,72,97],'sodium':[15,19,15,7,11,23,24,27,10,8,18,15,11,19,6,15,19,24,6,7],'alcohol':[4.7,4.9,0.9,5.2,5.0,4.6,5.5,4.7,4.3,3.7,4.6,4.1,4.2,4.7,5.0,2.3,4.4,4.9,2.9,4.2],'cost':[0.43,0.43,0.48,0.73,0.77,0.28,0.40,0.42,0.43,0.40,0.44,0.46,0.50,0.76,0.79,0.38,0.43,0.43,0.46,0.47]})

# %%
df
# Out:
#                     Name  Calories  sodium  alcohol  cost
# 0              Budweiser       144      15      4.7  0.43
# 1                Schlitz       151      19      4.9  0.43
# 2              Lowenbrau       157      15      0.9  0.48
# 3            Kronenbourg       170       7      5.2  0.73
# 4               Heineken       152      11      5.0  0.77
# 5          Old_Milwaukee       145      23      4.6  0.28
# 6             Augsberger       175      24      5.5  0.40
# 7   Srohs_Bohemian_Style       149      27      4.7  0.42
# 8            Miller_Lite        99      10      4.3  0.43
# 9        Budweiser_Light       113       8      3.7  0.40
# 10                 Coors       140      18      4.6  0.44
# 11            Coors_Ligh       102      15      4.1  0.46
# 12        Michelob_Light       135      11      4.2  0.50
# 13                 Becks       150      19      4.7  0.76
# 14                 Kirin       149       6      5.0  0.79
# ...

# %%
df.to_csv("beersData.csv")

# %%
pd.read_csv("beersData.csv")
# Out:
#     Unnamed: 0                  Name  Calories  sodium  alcohol  cost
# 0            0             Budweiser       144      15      4.7  0.43
# 1            1               Schlitz       151      19      4.9  0.43
# 2            2             Lowenbrau       157      15      0.9  0.48
# 3            3           Kronenbourg       170       7      5.2  0.73
# 4            4              Heineken       152      11      5.0  0.77
# 5            5         Old_Milwaukee       145      23      4.6  0.28
# 6            6            Augsberger       175      24      5.5  0.40
# 7            7  Srohs_Bohemian_Style       149      27      4.7  0.42
# 8            8           Miller_Lite        99      10      4.3  0.43
# 9            9       Budweiser_Light       113       8      3.7  0.40
# 10          10                 Coors       140      18      4.6  0.44
# 11          11            Coors_Ligh       102      15      4.1  0.46
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
crime = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv")

# %%
crime.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
#convert the type of the column year to datetime64
crime.Year = pd.to_datetime(crime.Year,format='%Y')
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     datetime64[ns]
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: datetime64[ns](1), int64(11)
# memory usage: 5.3 KB

# %%
crime.head()
# Out:
#         Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 2 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 3 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 4 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
#Return the first 3 rows of the data frame df
df =crime
df.iloc[:3]
# Out:
#         Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 2 1962-01-01   185771000  3752200   301510   3450700    8530          17550
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800

# %%
#selecting just the 'Vehicle_Theft' and 'robbery' columns from the Dataframe df 
df.loc[:,['Vehicle_Theft',"Robbery"]].head()
# Out:
#    Vehicle_Theft  Robbery
# 0         328200   107840
# 1         336000   106670
# 2         366800   110860
# 3         408300   116470
# 4         472800   130390

# %%
#selecting the data in rows [4,5,7,8] and in columns ['Vehicle_Theft','Robbery']
df.loc[df.index[[4,5,7,8]],['Vehicle_Theft','Robbery']]
# Out:
#    Vehicle_Theft  Robbery
# 4         472800   130390
# 5         496900   138690
# 7         659800   202910
# 8         783600   262840

# %%
#Selecting only the rows where the number of Robbery is greater than 15,000

# %%
df[df['Robbery'] > 15000]
# Out:
#          Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960-01-01   179323175   3384200   288460   3095700    9110          17190
# 1  1961-01-01   182992000   3488000   289390   3198600    8740          17220
# 2  1962-01-01   185771000   3752200   301510   3450700    8530          17550
# 3  1963-01-01   188483000   4109500   316970   3792500    8640          17650
# 4  1964-01-01   191141000   4564600   364220   4200400    9360          21420
# 5  1965-01-01   193526000   4739400   387390   4352000    9960          23410
# 6  1966-01-01   195576000   5223500   430180   4793300   11040          25820
# 7  1967-01-01   197457000   5903400   499930   5403500   12240          27620
# 8  1968-01-01   199399000   6720200   595010   6125200   13800          31670
# 9  1969-01-01   201385000   7410900   661870   6749000   14760          37170
# 10 1970-01-01   203235298   8098000   738820   7359200   16000          37990
# ...

# %%
#calculating the mean for each different year in df
df.groupby('Year')['Robbery'].mean()
# Out:
# Year
# 1960-01-01    107840
# 1961-01-01    106670
# 1962-01-01    110860
# 1963-01-01    116470
# 1964-01-01    130390
# 1965-01-01    138690
# 1966-01-01    157990
# 1967-01-01    202910
# 1968-01-01    262840
# 1969-01-01    298850
# 1970-01-01    349860
# 1971-01-01    387700
# 1972-01-01    376290
# 1973-01-01    384220
# 1974-01-01    442400
# 1975-01-01    470500
# 1976-01-01    427810
# 1977-01-01    412610
# 1978-01-01    426930
# 1979-01-01    480700
# 1980-01-01    565840
# 1981-01-01    592910
# 1982-01-01    553130
# 1983-01-01    506570
# 1984-01-01    485010
# 1985-01-01    497870
# 1986-01-01    542775
# 1987-01-01    517704
# 1988-01-01    542970
# 1989-01-01    578330
# 1990-01-01    639270
# 1991-01-01    687730
# 1992-01-01    672480
# 1993-01-01    659870
# 1994-01-01    618950
# 1995-01-01    580510
# 1996-01-01    535590
# 1997-01-01    498534
# 1998-01-01    446625
# 1999-01-01    409371
# 2000-01-01    408016
# 2001-01-01    423557
# 2002-01-01    420806
# ...

# %%
#Sort df first by the value in the "Murder" in decending order,
#Then by the value in the "Violent" column in ascending order

# %%
df.sort_values(by=["Murder",'Violent'],ascending=[False,True])
# Out:
#          Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 31 1991-01-01   252177000  14872900  1911770  12961100   24700         106590
# 33 1993-01-01   257908000  14144800  1926020  12218800   24530         106010
# 32 1992-01-01   255082000  14438200  1932270  12505900   23760         109060
# 30 1990-01-01   248709873  14475600  1820130  12655500   23440         102560
# 34 1994-01-01   260341000  13989500  1857670  12131900   23330         102220
# 20 1980-01-01   225349264  13408300  1344520  12063700   23040          82990
# 21 1981-01-01   229146000  13423800  1361820  12061900   22520          82500
# 35 1995-01-01   262755000  13862700  1798790  12063900   21610          97470
# 29 1989-01-01   248239000  14251400  1646040  12605400   21500          94500
# 19 1979-01-01   220099000  12249500  1208030  11041500   21460          76390
# 22 1982-01-01   231534000  12974400  1322390  11652000   21010          78770
# ...

# %%
df = pd.read_csv('https://raw.githubusercontent.com/vincentarelbundock/Rdatasets/master/datasets.csv')

# %%
df
# Out:
#      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1709     vcd       UKSoccer
# 1710     vcd   VisualAcuity
# 1711     vcd        VonBort
# 1712     vcd     WeldonDice
# 1713     vcd     WomenQueue
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# ...

# %%
df.columns
# Out:
# Index(['Package', 'Item', 'Title', 'Rows', 'Cols', 'n_binary', 'n_character',
#        'n_factor', 'n_logical', 'n_numeric', 'CSV', 'Doc'],
#       dtype='object')

# %%
df['Item']
# Out:
# 0             Affairs
# 1        ArgentinaCPI
# 2           BankWages
# 3       BenderlyZwick
# 4           BondYield
#             ...
# 1709         UKSoccer
# 1710     VisualAcuity
# 1711          VonBort
# 1712       WeldonDice
# 1713       WomenQueue
# Name: Item, Length: 1714, dtype: object

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1709     vcd       UKSoccer
# 1710     vcd   VisualAcuity
# 1711     vcd        VonBort
# 1712     vcd     WeldonDice
# 1713     vcd     WomenQueue
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# ...

# %%
#Extracting particular data through index
df.columns
# Out:
# Index(['Package', 'Item', 'Title', 'Rows', 'Cols', 'n_binary', 'n_character',
#        'n_factor', 'n_logical', 'n_numeric', 'CSV', 'Doc'],
#       dtype='object')

# %%
df[['Item']][4:25]
# Out:
#                Item
# 4         BondYield
# 5   CartelStability
# 6         CASchools
# 7       ChinaIncome
# 8       CigarettesB
# 9      CigarettesSW
# 10  CollegeDistance
# 11     ConsumerGood
# 12          CPS1985
# 13          CPS1988
# 14          CPSSW04
# 15           CPSSW3
# 16           CPSSW8
# 17        CPSSW9204
# 18        CPSSW9298
# 19   CPSSWEducation
# 20       CreditCard
# 21        DJFranses
# 22         DJIA8012
# 23     DoctorVisits
# 24      DutchAdvert

# %%
sorted(df['Item'])
# Out:
# ['ACF1',
#  'AHCAvote2017',
#  'AMSsurvey',
#  'Accident',
#  'AccordPrice',
#  'AccountantsAuditorsPct',
#  'Adler',
#  'Affairs',
#  'Aids2',
#  'AirPassengers',
#  'Airline',
#  'Airlines',
#  'Airq',
#  'Alcohol',
#  'Alfalfa',
#  'AlitoConfirmation',
#  'Amyloid',
#  'Angell',
#  'Animals',
#  'Animals2',
#  'Anscombe',
#  'AppleStock',
#  'Arabidopsis',
#  'Arbuthnot',
#  'Arca',
#  'ArcheryData',
#  'ArgentinaCPI',
#  'Armada',
#  'Arrests',
#  'Arthritis',
#  'AthleteGrad',
#  'AudioVisual',
#  'AustralianElectionPolling',
#  'AustralianElections',
#  'Auto',
#  'AutoPollution',
#  'BCG',
#  'BEPS',
#  'BJsales',
#  'BOD',
#  'Backpack',
#  'BankWages',
#  'Baseball',
#  'BaseballTimes',
#  'BaseballTimes2017',
#  'Baumann',
#  'Bechtoldt',
#  'Bechtoldt.1',
#  'Bechtoldt.2',
#  'BeeStings',
#  'BenderlyZwick',
#  'Benefits',
#  'Bfox',
#  'Bids',
#  'BirdCalcium',
#  'BirdNest',
#  'Birthdays',
#  'Births',
#  'Births2015',
#  'Births78',
#  'Blackmore',
#  'Blood1',
# ...

# %%
for i in df:
    print(df[[i]])
# Out:
#      Package
# 0        AER
# 1        AER
# 2        AER
# 3        AER
# 4        AER
# ...      ...
# 1709     vcd
# 1710     vcd
# 1711     vcd
# 1712     vcd
# 1713     vcd
#
# [1714 rows x 1 columns]
#                Item
# 0           Affairs
# 1      ArgentinaCPI
# 2         BankWages
# 3     BenderlyZwick
# 4         BondYield
# ...             ...
# 1709       UKSoccer
# 1710   VisualAcuity
# 1711        VonBort
# 1712     WeldonDice
# 1713     WomenQueue
#
# [1714 rows x 1 columns]
#                                                   Title
# 0                      Fair's Extramarital Affairs Data
# 1                     Consumer Price Index in Argentina
# 2                                            Bank Wages
# 3     Benderly and Zwick Data: Inflation, Growth and...
# 4                                       Bond Yield Data
# ...                                                 ...
# 1709                                   UK Soccer Scores
# ...

# %%
#creating a new column and assigning value
df["teja"] = "gummala"

# %%
df
# Out:
#      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1709     vcd       UKSoccer
# 1710     vcd   VisualAcuity
# 1711     vcd        VonBort
# 1712     vcd     WeldonDice
# 1713     vcd     WomenQueue
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# ...

# %%
#updating new columns
df['teja1'] = df['Package']

# %%
df
# Out:
#      Package           Item  \
# 0        AER        Affairs
# 1        AER   ArgentinaCPI
# 2        AER      BankWages
# 3        AER  BenderlyZwick
# 4        AER      BondYield
# ...      ...            ...
# 1709     vcd       UKSoccer
# 1710     vcd   VisualAcuity
# 1711     vcd        VonBort
# 1712     vcd     WeldonDice
# 1713     vcd     WomenQueue
#
#                                                   Title  Rows  Cols  n_binary  \
# 0                      Fair's Extramarital Affairs Data   601     9         2
# 1                     Consumer Price Index in Argentina    80     2         0
# 2                                            Bank Wages   474     4         2
# 3     Benderly and Zwick Data: Inflation, Growth and...    31     5         0
# 4                                       Bond Yield Data    60     2         0
# ...                                                 ...   ...   ...       ...
# ...

# %%
pd.Categorical(df['Item'])
# Out:
# [Affairs, ArgentinaCPI, BankWages, BenderlyZwick, BondYield, ..., UKSoccer, VisualAcuity, VonBort, WeldonDice, WomenQueue]
# Length: 1714
# Categories (1658, object): [ACF1, AHCAvote2017, AMSsurvey, Accident, ..., yrbss, yrbss_samp, yugo_sales, yule]

# %%
df.iloc[[1,2,3,55,7]]
# Out:
#    Package           Item                                              Title  \
# 1      AER   ArgentinaCPI                  Consumer Price Index in Argentina
# 2      AER      BankWages                                         Bank Wages
# 3      AER  BenderlyZwick  Benderly and Zwick Data: Inflation, Growth and...
# 55     AER    MotorCycles                    Motor Cycles in The Netherlands
# 7      AER    ChinaIncome                  Chinese Real National Income Data
#
#     Rows  Cols  n_binary  n_character  n_factor  n_logical  n_numeric  \
# 1     80     2         0            0         0          0          2
# 2    474     4         2            0         3          0          1
# 3     31     5         0            0         0          0          5
# 55    48     2         0            0         0          0          2
# 7     37     5         0            0         0          0          5
#
#                                                   CSV  \
# ...
